# %% [markdown]
# # Mount Google Drive

# %%
# Load library google drive
from google.colab import drive
drive.mount('gdrive')

root = '/content/gdrive/MyDrive/Colab Notebooks/ML Bangkit/'
# Out:
# Drive already mounted at gdrive; to attempt to forcibly remount, call drive.mount("gdrive", force_remount=True).

# %% [markdown]
# # Load Dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(root + 'Datasets/FIXED/fixed_data.xlsx')
df.reset_index(drop=True)
df.head()
# Out:
#                                                 text  label
# 0  nice hotel expensive parking got good deal sta...  hotel
# 1  ok nothing special charge diamond member hilto...  hotel
# 2  nice rooms not 4* experience hotel monaco seat...  hotel
# 3  unique \tgreat stay \twonderful time hotel mon...  hotel
# 4  great stay great stay \twent seahawk game awes...  hotel

# %% [markdown]
# # Declare Preprocessing Method

# %%
import re
import string
import nltk
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Lowering Text
def lower(text):
  return text.lower()

# Lexical Analysis
exclist = string.punctuation + string.digits
def remove_punc_and_number(text):
  newtext = ''.join(x for x in text if x not in exclist)
  return newtext

# Remove Leading Space
def remove_space(text):
  splited = text.split()
  splited = [word.strip() for word in splited]
  return ' '.join(splited)

# Stemming
ps = PorterStemmer()
nltk.download('punkt')
def stem(text):
  words = word_tokenize(text)
  stemmed = [ps.stem(word) for word in words]
  return ' '.join(stemmed)

# Lemmatizing
lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
nltk.download('omw-1.4')
def lemmatize(text):
  words = word_tokenize(text)
  lemmatized = [lemmatizer.lemmatize(word) for word in words]
  return ' '.join(lemmatized)

# Remove Stopwords
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
def remove_stopwords(text):
  words = word_tokenize(text)
  words = [word for word in words if word not in stopwords]
  return ' '.join(words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Preprocessing Umum
# Lower, Remove Punctuation and Number, remove leading space, Remove Stopwords

# %%
df.text = [lower(str(text)) for text in df.text]
df.text = [remove_punc_and_number(text) for text in df.text]
df.text = [remove_space(text) for text in df.text]
df.text = [remove_stopwords(text) for text in df.text]

# %% [markdown]
# # Preprocessing Skenario 1
# With Stem

# %%
df1 = df.copy()
df1.text = [stem(text) for text in df1.text]
df1.to_excel(root + 'Datasets/preprocessed/data_skenario_1.xlsx')

# %% [markdown]
# # Preprocessing Skenario 2
# With Lemmatize

# %%
df2 = df.copy()
df2.text = [lemmatize(text) for text in df2.text]
df2.to_excel(root + 'Datasets/preprocessed/data_skenario_2.xlsx')

# %% [markdown]
# # Preprocessing Skenario 3
# W/o Stem and Lemmatize

# %%
df.to_excel(root + 'Datasets/preprocessed/data_skenario_3.xlsx')
